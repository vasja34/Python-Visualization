# %% [markdown]
# ## Line plots on multiple facets
# * https://seaborn.pydata.org/examples/faceted_lineplot.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

plt.style.use('seaborn')
sns.set(style="ticks")

# %%
dots = sns.load_dataset("dots")
dots.shape
# Out:
# (848, 5)

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   align        848 non-null    object
#  1   choice       848 non-null    object
#  2   time         848 non-null    int64
#  3   coherence    848 non-null    float64
#  4   firing_rate  848 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 33.2+ KB

# %%
dots.coherence.unique()
# Out:
# array([ 0. ,  3.2,  6.4, 12.8, 25.6, 51.2])

# %%
# Define a palette to ensure that colors will be
# shared across the facets
palette = dict(zip(dots.coherence.unique(),
                   sns.color_palette("rocket_r", 6)))
palette
# Out:
# {0.0: (0.96516917, 0.70776351, 0.5606593),
#  3.2: (0.95381595, 0.46373781, 0.31769923),
#  6.4: (0.8833417, 0.19830556, 0.26014181),
#  12.8: (0.67824099, 0.09192342, 0.3504148),
#  25.6: (0.43860848, 0.12177004, 0.34119475),
#  51.2: (0.20973515, 0.09747934, 0.24238489)}

# %%
sns.relplot(x="time", y="firing_rate", 
            hue="coherence",  col="align", size="choice",
            size_order=["T1", "T2"],
            height=5, aspect=.75,  facet_kws=dict(sharex=False),
            data=dots, kind="line", legend="full")

# %%
# Plot the lines on two facets
sns.relplot(x="time", y="firing_rate",
            hue="coherence", size="choice", col="align",
            size_order=["T1", "T2"], palette=palette,
            height=5, aspect=.75, facet_kws=dict(sharex=False),
            kind="line", legend="full", data=dots)

# %%
tips = sns.load_dataset("tips")
g = sns.relplot(x="total_bill", y="tip", 
                col="smoker", hue="day", data=tips)

# %%
g = sns.relplot(x="total_bill", y="tip", 
                col="smoker", hue="day", kind="line", data=tips)

# %%
g = sns.lmplot(x="total_bill", y="tip", 
                col="smoker", data=tips)

# %% [markdown]
# * [Joint kernel density estimate — seaborn 0.9.0 documentation](https://seaborn.pydata.org/examples/joint_kde.html#joint-kernel-density-estimate)
# * [Hexbin plot with marginal distributions — seaborn 0.9.0 documentation](https://seaborn.pydata.org/examples/hexbin_marginals.html)
# * [Linear regression with marginal distributions — seaborn 0.9.0 documentation](https://seaborn.pydata.org/examples/regression_marginals.html)

# %%
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
sns.set(style="darkgrid")
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
print(tips.shape)
tips.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Shift+Enter 키를 누르면 도움말을 보실 수 있습니다.
g = sns.jointplot(x="total_bill", y="tip", data=tips, kind='reg')

# %%
g = sns.jointplot(x="total_bill", y="tip", data=tips, kind='kde')

# %%
g = sns.jointplot(x="total_bill", y="tip", data=tips, kind='hex')

# %%
tips[["total_bill", "tip"]].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.set(style="whitegrid")
g = sns.jointplot("total_bill", "tip", data=tips, kind="reg",
                  xlim=(0, 60), ylim=(0, 12), color="m", height=7)

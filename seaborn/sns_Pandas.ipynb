# %% [markdown]
# # Data Visualization with Pandas & Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

plt.style.use('seaborn')
sns.set()

# %% [markdown]
# ## Line Plots

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.petal_length.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar Plots

# %%
data = pd.Series(np.random.rand(5), index=list('abcde'))

# %%
data
# Out:
# a    0.837914
# b    0.207093
# c    0.634690
# d    0.887662
# e    0.721858
# dtype: float64

# %%
data.plot.bar(color='b', alpha=1)
# Out:
# <AxesSubplot:>

# %%
data.plot.barh(color='r', alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df =pd.DataFrame(np.random.rand(5, 3),index=['one', 'two', 'three', 'four', 'five'], 
                 columns=pd.Index(list("ABC")))

# %%
df.head()
# Out:
#               A         B         C
# one    0.111028  0.181169  0.506929
# two    0.302475  0.331367  0.520455
# three  0.241609  0.031291  0.673760
# four   0.518297  0.270134  0.421207
# five   0.861936  0.737899  0.830877

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha=1)
# Out:
# <AxesSubplot:>

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
day_size=pd.crosstab(tips["day"],tips["size"])

# %%
day_size
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
day_size.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
tips['tips_perc'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_perc
# 0       16.99  1.01  Female     No  Sun  Dinner     2   0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3   0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3   0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2   0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4   0.172069

# %%
sns.barplot(x='day', y='tips_perc', data=tips, orient='v')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tips_perc'>

# %%
sns.barplot(x='day', y='tips_perc', hue='time', data=tips, orient='v')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tips_perc'>

# %% [markdown]
# ## Histograms and Density Plots

# %%
tips['tips_perc'].plot.hist(bins=70)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(tips['tips_perc'], kde=True, bins=50, color="r")
# Out:
# <AxesSubplot:xlabel='tips_perc', ylabel='Count'>

# %% [markdown]
# ## Scatter or Point Plots

# %%
sns.regplot(x='sepal_length', y='petal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue="species")

# %% [markdown]
# ## Facet Grids and Categorical Data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_perc
# 0       16.99  1.01  Female     No  Sun  Dinner     2   0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3   0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3   0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2   0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4   0.172069

# %%
sns.catplot(x='day', y='tips_perc', hue='time', col='smoker', kind='bar', data=tips)

# %%
sns.catplot(x='day', y='tips_perc', row='time',col='smoker',kind='bar', data=tips)

# %%
sns.catplot(x='day', y='tips_perc', row='time',col='smoker',kind='box', data=tips)
